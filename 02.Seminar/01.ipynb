# %% [markdown]
# csv - comma-separated values - данные разделенные запятой
# - df = pd.read_csv('file.csv', # функция считывания внешнего файла формата csv (можно выбрать необходимый формат)
#                  encoding='windows-1251',
#                  sep = ';',
#                  index_col='название_столбца',
#                  parse_dates=['Date'],
#                  dayfirst=True)
# 'file.csv' - путь к файлу,
#
# sep - разделитель sep(по умолчаниию ',')
#
# encoding – параметр в read_csv, отвечает за кодировку текста, которая может быть различной. Самая распространённая – utf
#
# index_col='название_столбца' - название столбца, который будет выступать как столбец индексов
#
# index_col=[0] - индекс столбца, который будет выступать как столбец индексов
#
# parse_dates – указывает, стоит ли воспринимать даты как даты (по умолчанию они воспринимаются пандасом как строки).
#     пример pd.read_csv(path, parse_dates=['some_date', 'another_date'])
#     Параметр с датами может принимать несколько значений:
#     True – пытается перевести в дату первую колонку
#     список колонок – parse_dates=['some_date', 'another_date']
#     пытается перевести в дату указанные в списке колонки и столбцы create_data, payment_data
#     будут обрабатываться как даты
#
# dayfirst=True  - первое значение в дате это день или нет - True/False
#
# df['Date'].dt.name - номер дня недели в соответствии с данными в колонке с датами
#
# df['Date'].dt.name() - название дня недели в соответствии с данными в колонке с датами
#
# df['Date'].dt.month - номер месяца в соответствии с данными в колонке с датами
#
# df['Date'].dt.month() - название месяца в соответствии с данными в колонке с датами

# %% [markdown]
# Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
# - Считать данные с помощью pandas
# - Вывести на экран первые 5 строк
# - Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd
df=pd.read_csv('laptop_price.csv', encoding="cp1251", index_col='laptop_ID')
df.head(5)
# Out:
#           Company      Product   TypeName  Inches  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3
# 2           Apple  Macbook Air  Ultrabook    13.3
# 3              HP       250 G6   Notebook    15.6
# 4           Apple  MacBook Pro  Ultrabook    15.4
# 5           Apple  MacBook Pro  Ultrabook    13.3
#
#                              ScreenResolution                         Cpu  \
# laptop_ID
# 1          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 2                                    1440x900        Intel Core i5 1.8GHz
# 3                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 4          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 5          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
#
#             Ram               Memory                           Gpu  OpSys  \
# laptop_ID
# 1           8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS
# 2           8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS
# 3           8GB            256GB SSD         Intel HD Graphics 620  No OS
# 4          16GB            512GB SSD            AMD Radeon Pro 455  macOS
# 5           8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS
#
#            Weight  Price_euros
# laptop_ID
# 1          1.37kg      1339.69
# 2          1.34kg       898.94
# 3          1.86kg       575.00
# 4          1.83kg      2537.45
# 5          1.37kg      1803.60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1303 entries, 1 to 1320
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 132.3+ KB

# %%
df.describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %%
df.isna()
# Out:
#            Company  Product  TypeName  Inches  ScreenResolution    Cpu    Ram  \
# laptop_ID
# 1            False    False     False   False             False  False  False
# 2            False    False     False   False             False  False  False
# 3            False    False     False   False             False  False  False
# 4            False    False     False   False             False  False  False
# 5            False    False     False   False             False  False  False
# ...            ...      ...       ...     ...               ...    ...    ...
# 1316         False    False     False   False             False  False  False
# 1317         False    False     False   False             False  False  False
# 1318         False    False     False   False             False  False  False
# 1319         False    False     False   False             False  False  False
# 1320         False    False     False   False             False  False  False
#
#            Memory    Gpu  OpSys  Weight  Price_euros
# laptop_ID
# 1           False  False  False   False        False
# 2           False  False  False   False        False
# 3           False  False  False   False        False
# 4           False  False  False   False        False
# 5           False  False  False   False        False
# ...           ...    ...    ...     ...          ...
# 1316        False  False  False   False        False
# 1317        False  False  False   False        False
# 1318        False  False  False   False        False
# 1319        False  False  False   False        False
# 1320        False  False  False   False        False
#
# [1303 rows x 12 columns]

# %% [markdown]
# Ответьте на несколько вопросов
#
# 3.1 Ноутбуков от какой компании больше всего в наборе данных?
#
# 3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?
#
# 3.3 Какой самый дорогой ноутбук в данных?
#
# Выведите все характеристики только по этому ноутбуку
#
# Если таких ноутбуков несколько, то выводите их всех

# %%
df['Company'].max()
# Out:
# 'Xiaomi'

# %%
df['Company'].value_counts().head(1)
# Out:
# Dell    297
# Name: Company, dtype: int64

# %%
df["Price_euros"].max(), df["Price_euros"].min()
# Out:
# (6099.0, 174.0)

# %%
df[df["Price_euros"] == df["Price_euros"].max()]
# Out:
#           Company    Product TypeName  Inches  \
# laptop_ID
# 200         Razer  Blade Pro   Gaming    17.3
#
#                               ScreenResolution                          Cpu  \
# laptop_ID
# 200        4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz
#
#             Ram   Memory                      Gpu       OpSys  Weight  \
# laptop_ID
# 200        32GB  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg
#
#            Price_euros
# laptop_ID
# 200             6099.0

# %% [markdown]
# Ответьте на несколько вопросов
#
# 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
#
# Выведите только следующие характеристики:
#
# Компания
#
# Типа ноутбука
#
# Диагональ
#
# Стоимость
#
# Если таких ноутбуков несколько, то выводите их всех
#
# 4.2 Сколько стоит самый дорогой ноутбук у компании HP?
#
# 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
#
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %%
df['Inches'].min()
# Out:
# 10.1

# %%
df[df["Inches"] == df["Inches"].min()][["Company", "TypeName", "Inches", "Price_euros"]]
# Out:
#           Company            TypeName  Inches  Price_euros
# laptop_ID
# 51         Lenovo  2 in 1 Convertible    10.1       319.00
# 1097       Lenovo  2 in 1 Convertible    10.1       646.27
# 1129       Lenovo  2 in 1 Convertible    10.1       549.00
# 1141       Lenovo  2 in 1 Convertible    10.1       479.00

# %%
df[df["Company"]== "HP"].max()
# Out:
# Company                                        HP
# Product                                  Zbook 17
# TypeName                              Workstation
# Inches                                       17.3
# ScreenResolution            Touchscreen 2560x1440
# Cpu                 Intel Xeon E3-1535M v5 2.9GHz
# Ram                                           8GB
# Memory                                    8GB SSD
# Gpu                          Nvidia Quadro M3000M
# OpSys                                   Windows 7
# Weight                                        3kg
# Price_euros                                4389.0
# dtype: object

# %% [markdown]
# 5.1 Выберите ноутбук клиенту
#
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?
#
# 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?
#
# 5.3 Что дешевле?
#
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
df[(df["Ram"]=="8GB") | (df['Ram']=="16GB")]
# Out:
#           Company               Product            TypeName  Inches  \
# laptop_ID
# 1           Apple           MacBook Pro           Ultrabook    13.3
# 2           Apple           Macbook Air           Ultrabook    13.3
# 3              HP                250 G6            Notebook    15.6
# 4           Apple           MacBook Pro           Ultrabook    15.4
# 5           Apple           MacBook Pro           Ultrabook    13.3
# ...           ...                   ...                 ...     ...
# 1303       Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1307         Asus  ZenBook UX305CA-UBM1           Ultrabook    13.3
# 1311       Lenovo    IdeaPad Y700-15ISK            Notebook    15.6
# 1313         Dell         Inspiron 3567            Notebook    15.6
# 1317       Lenovo        Yoga 900-13ISK  2 in 1 Convertible    13.3
#
#                                      ScreenResolution  \
# laptop_ID
# 1                  IPS Panel Retina Display 2560x1600
# 2                                            1440x900
# 3                                   Full HD 1920x1080
# 4                  IPS Panel Retina Display 2880x1800
# 5                  IPS Panel Retina Display 2560x1600
# ...                                               ...
# 1303       IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1307                      IPS Panel Full HD 1920x1080
# 1311                      IPS Panel Full HD 1920x1080
# 1313                                         1366x768
# 1317       IPS Panel Quad HD+ / Touchscreen 3200x1800
#
#                                    Cpu   Ram               Memory  \
# laptop_ID
# 1                 Intel Core i5 2.3GHz   8GB            128GB SSD
# 2                 Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3           Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 4                 Intel Core i7 2.7GHz  16GB            512GB SSD
# 5                 Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                ...   ...                  ...
# 1303        Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1307          Intel Core M 6Y30 0.9GHz   8GB            512GB SSD
# 1311       Intel Core i7 6700HQ 2.6GHz   8GB              1TB HDD
# 1313        Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 1317        Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
#
#                                     Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1          Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 2                Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3                 Intel HD Graphics 620       No OS  1.86kg       575.00
# 4                    AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 5          Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                                 ...         ...     ...          ...
# 1303              Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1307              Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1311            Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1313                 AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1317              Intel HD Graphics 520  Windows 10   1.3kg      1499.00
#
# [819 rows x 12 columns]

# %%
df[(df["Ram"].isin(["8GB", "16GG"])) & (df["OpSys"]=="Windows 10") & (df["Price_euros"] < 500)].shape[0]
# Out:
# 13

# %%
df[(df["Company"]=="MSI") & (df["Gpu"]=="Nvidia GeForce GTX 1050 Ti") & (df["Inches"] != 15.6)]
# Out:
#           Company        Product TypeName  Inches   ScreenResolution  \
# laptop_ID
# 336           MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 400           MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 732           MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 931           MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
# 1174          MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
#
#                                    Cpu   Ram                Memory  \
# laptop_ID
# 336        Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 400        Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 732        Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 931        Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1174       Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                                   Gpu       OpSys Weight  Price_euros
# laptop_ID
# 336        Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# 400        Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1349.00
# 732        Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1348.48
# 931        Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1599.00
# 1174       Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1492.80

# %%
df[(df["Cpu"]=="Intel Core i7 7700HQ 2.8GHz") | (df["Cpu"]=="Intel Core i7 7600U 2.8GHz")]
# Out:
#           Company                                    Product   TypeName  \
# laptop_ID
# 42           Dell                              Inspiron 7577     Gaming
# 59            MSI                                 GS73VR 7RG     Gaming
# 67           Asus                                ZenBook Pro  Ultrabook
# 71           Asus  FX753VE-GC093 (i7-7700HQ/12GB/1TB/GeForce     Gaming
# 77           Asus  FX503VD-E4022T (i7-7700HQ/8GB/1TB/GeForce     Gaming
# ...           ...                                        ...        ...
# 1232         Asus                                  ROG Strix     Gaming
# 1247          MSI                                 GL62M 7RDX     Gaming
# 1249        Razer                                  Blade Pro     Gaming
# 1251          MSI                              GE72VR Apache     Gaming
# 1263         Asus                         Rog GL553VE-FY052T     Gaming
#
#            Inches             ScreenResolution                          Cpu  \
# laptop_ID
# 42           15.6  IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 59           17.3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 67           15.6            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 71           17.3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 77           15.6            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# ...           ...                          ...                          ...
# 1232         17.3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 1247         15.6            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 1249         14.0            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 1251         17.3            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 1263         15.6  IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#             Ram                Memory                         Gpu       OpSys  \
# laptop_ID
# 42         16GB  256GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10
# 59         16GB  256GB SSD +  2TB HDD     Nvidia GeForce GTX 1070  Windows 10
# 67         16GB             512GB SSD  Nvidia GeForce GTX 1050 Ti  Windows 10
# 71         12GB               1TB HDD  Nvidia GeForce GTX 1050 Ti       Linux
# 77          8GB               1TB HDD     Nvidia GeForce GTX 1050  Windows 10
# ...         ...                   ...                         ...         ...
# 1232       16GB  256GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10
# 1247        8GB  128GB SSD +  1TB HDD     Nvidia GeForce GTX 1050  Windows 10
# 1249       16GB               1TB SSD     Nvidia GeForce GTX 1060  Windows 10
# 1251       16GB  256GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10
# 1263       16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10
#
#            Weight  Price_euros
# laptop_ID
# 42         2.65kg       1499.0
# 59         2.43kg       2449.0
# 67          1.8kg       1983.0
# 71            3kg        949.0
# 77          2.2kg        949.0
# ...           ...          ...
# 1232        2.9kg       1949.0
# 1247        2.2kg       1149.0
# 1249       1.95kg       3499.0
# 1251        2.7kg       1598.0
# 1263        2.5kg       1600.0
#
# [159 rows x 12 columns]

# %% [markdown]
# Задача 6
#
# Найдите самый легкий ноутбук
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
df["Weight"]=df["Weight"].str.replace("kg", "").astype("float")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df["Weight"]=df["Weight"].str.replace("kg", "").astype("float")
#
# File D:\github\jupiter\.notebook\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File D:\github\jupiter\.notebook\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File D:\github\jupiter\.notebook\lib\site-packages\pandas\core\strings\accessor.py:181, in StringMethods.__init__(self, data)
#     178 def __init__(self, data) -> None:
#     179     from pandas.core.arrays.string_ import StringDtype
# --> 181     self._inferred_dtype = self._validate(data)
#     182     self._is_categorical = is_categorical_dtype(data.dtype)
#     183     self._is_string = isinstance(data.dtype, StringDtype)
#
# File D:\github\jupiter\.notebook\lib\site-packages\pandas\core\strings\accessor.py:235, in StringMethods._validate(data)
#     232 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     234 if inferred_dtype not in allowed_types:
# --> 235     raise AttributeError("Can only use .str accessor with string values!")
#     236 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df["Weight"].idxmin()
# Out:
# 51

# %%
df.loc[df["Weight"].idxmin()]
# Out:
# Company                                      Lenovo
# Product                                   Yoga Book
# TypeName                         2 in 1 Convertible
# Inches                                         10.1
# ScreenResolution    IPS Panel Touchscreen 1920x1200
# Cpu                     Intel Atom x5-Z8550 1.44GHz
# Ram                                             4GB
# Memory                           64GB Flash Storage
# Gpu                           Intel HD Graphics 400
# OpSys                                       Android
# Weight                                         0.69
# Price_euros                                   319.0
# Name: 51, dtype: object

# %%
df[df["Weight"] == df["Weight"].min()][["Product","Weight"]]
# Out:
#              Product  Weight
# laptop_ID
# 51         Yoga Book    0.69
# 1097       Yoga Book    0.69
# 1129       Yoga Book    0.69
# 1141       Yoga Book    0.69
